# %%
import pandas as pd
import numpy as np
import re

# %%
#CSV to Load
zillow_data= 'C:/Users/laure/OneDrive/Desktop/classfolder/zillow_data.csv'
zillow_df=pd.read_csv(zillow_data)
zillow_df.head()
# Out:
#    RegionID  RegionName  SizeRank          MsaName  Jan-14  Feb-14  Mar-14  \
# 0     95314       87120       193  Albuquerque, NM   791.0   823.0   808.0
# 1     95315       87121       278  Albuquerque, NM  1010.0   989.0   966.0
# 2     95318       87124       464  Albuquerque, NM   943.0   913.0   916.0
# 3     95304       87109       812  Albuquerque, NM   856.0   893.0   882.0
# 4     95303       87108      1076  Albuquerque, NM   500.0   544.0   531.0
#
#    Apr-14  May-14  Jun-14  ...  Oct-20  Nov-20  Dec-20  Jan-21  Feb-21  \
# 0   821.0   832.0   842.0  ...  1038.0  1023.0  1053.0  1055.0  1065.0
# 1   985.0   996.0  1011.0  ...  1257.0  1307.0  1296.0  1294.0  1277.0
# 2   931.0   948.0   959.0  ...  1206.0  1210.0  1203.0  1212.0  1239.0
# 3   878.0   871.0   883.0  ...  1091.0  1100.0  1071.0  1096.0  1126.0
# 4   534.0   523.0   499.0  ...   724.0   722.0   717.0   728.0   715.0
#
#    Mar-21  Apr-21  May-21  Jun-21  Jul-21
# 0  1068.0  1093.0  1111.0  1142.0  1177.0
# ...

# %%
zillow_df.columns.tolist()
# Out:
# ['RegionID',
#  'RegionName',
#  'SizeRank',
#  'MsaName',
#  'Jan-14',
#  'Feb-14',
#  'Mar-14',
#  'Apr-14',
#  'May-14',
#  'Jun-14',
#  'Jul-14',
#  'Aug-14',
#  'Sep-14',
#  'Oct-14',
#  'Nov-14',
#  'Dec-14',
#  'Jan-15',
#  'Feb-15',
#  'Mar-15',
#  'Apr-15',
#  'May-15',
#  'Jun-15',
#  'Jul-15',
#  'Aug-15',
#  'Sep-15',
#  'Oct-15',
#  'Nov-15',
#  'Dec-15',
#  'Jan-16',
#  'Feb-16',
#  'Mar-16',
#  'Apr-16',
#  'May-16',
#  'Jun-16',
#  'Jul-16',
#  'Aug-16',
#  'Sep-16',
#  'Oct-16',
#  'Nov-16',
#  'Dec-16',
#  'Jan-17',
#  'Feb-17',
#  'Mar-17',
#  'Apr-17',
#  'May-17',
#  'Jun-17',
#  'Jul-17',
#  'Aug-17',
#  'Sep-17',
#  'Oct-17',
#  'Nov-17',
#  'Dec-17',
#  'Jan-18',
#  'Feb-18',
#  'Mar-18',
#  'Apr-18',
#  'May-18',
#  'Jun-18',
#  'Jul-18',
#  'Aug-18',
#  'Sep-18',
#  'Oct-18',
#  'Nov-18',
#  'Dec-18',
#  'Jan-19',
#  'Feb-19',
#  'Mar-19',
#  'Apr-19',
#  'May-19',
#  'Jun-19',
#  'Jul-19',
#  'Aug-19',
#  'Sep-19',
#  'Oct-19',
#  'Nov-19',
#  'Dec-19',
# ...

# %%
zillow_df.drop('RegionID', axis=1)
# Out:
#       RegionName  SizeRank            MsaName  Jan-14  Feb-14  Mar-14  Apr-14  \
# 0          87120       193    Albuquerque, NM   791.0   823.0   808.0   821.0
# 1          87121       278    Albuquerque, NM  1010.0   989.0   966.0   985.0
# 2          87124       464    Albuquerque, NM   943.0   913.0   916.0   931.0
# 3          87109       812    Albuquerque, NM   856.0   893.0   882.0   878.0
# 4          87108      1076    Albuquerque, NM   500.0   544.0   531.0   534.0
# ...          ...       ...                ...     ...     ...     ...     ...
# 2228       27103      1368  Winston-Salem, NC   996.0  1050.0  1037.0  1036.0
# 2229       27104      2247  Winston-Salem, NC     NaN   940.0   940.0   966.0
# 2230       27012      3043  Winston-Salem, NC     NaN  1093.0     NaN  1095.0
# 2231       27101      4011  Winston-Salem, NC     NaN  1064.0  1030.0  1035.0
# 2232        1604      2069      Worcester, MA  1090.0  1087.0  1096.0  1089.0
#
# ...

# %%
zillow_df.drop('SizeRank', axis=1)
# Out:
#       RegionID  RegionName            MsaName  Jan-14  Feb-14  Mar-14  Apr-14  \
# 0        95314       87120    Albuquerque, NM   791.0   823.0   808.0   821.0
# 1        95315       87121    Albuquerque, NM  1010.0   989.0   966.0   985.0
# 2        95318       87124    Albuquerque, NM   943.0   913.0   916.0   931.0
# 3        95304       87109    Albuquerque, NM   856.0   893.0   882.0   878.0
# 4        95303       87108    Albuquerque, NM   500.0   544.0   531.0   534.0
# ...        ...         ...                ...     ...     ...     ...     ...
# 2228     69206       27103  Winston-Salem, NC   996.0  1050.0  1037.0  1036.0
# 2229     69207       27104  Winston-Salem, NC     NaN   940.0   940.0   966.0
# 2230     69169       27012  Winston-Salem, NC     NaN  1093.0     NaN  1095.0
# 2231     69204       27101  Winston-Salem, NC     NaN  1064.0  1030.0  1035.0
# 2232     58443        1604      Worcester, MA  1090.0  1087.0  1096.0  1089.0
#
# ...

# %%
zillow_df[['City', "State"]]=zillow_df.MsaName.str.split(",", expand=True,)

# %%
zillow_df.head()
# Out:
#    RegionID  RegionName  SizeRank          MsaName  Jan-14  Feb-14  Mar-14  \
# 0     95314       87120       193  Albuquerque, NM   791.0   823.0   808.0
# 1     95315       87121       278  Albuquerque, NM  1010.0   989.0   966.0
# 2     95318       87124       464  Albuquerque, NM   943.0   913.0   916.0
# 3     95304       87109       812  Albuquerque, NM   856.0   893.0   882.0
# 4     95303       87108      1076  Albuquerque, NM   500.0   544.0   531.0
#
#    Apr-14  May-14  Jun-14  ...  Dec-20  Jan-21  Feb-21  Mar-21  Apr-21  \
# 0   821.0   832.0   842.0  ...  1053.0  1055.0  1065.0  1068.0  1093.0
# 1   985.0   996.0  1011.0  ...  1296.0  1294.0  1277.0  1300.0  1300.0
# 2   931.0   948.0   959.0  ...  1203.0  1212.0  1239.0  1242.0  1260.0
# 3   878.0   871.0   883.0  ...  1071.0  1096.0  1126.0  1140.0  1164.0
# 4   534.0   523.0   499.0  ...   717.0   728.0   715.0   735.0   763.0
#
#    May-21  Jun-21  Jul-21         City  State
# ...

# %%
zillow_df.rename(columns={'RegionName': 'ZIP'}, inplace=True)

# %%
zillow_df.head()
# Out:
#    RegionID    ZIP  SizeRank          MsaName  Jan-14  Feb-14  Mar-14  Apr-14  \
# 0     95314  87120       193  Albuquerque, NM   791.0   823.0   808.0   821.0
# 1     95315  87121       278  Albuquerque, NM  1010.0   989.0   966.0   985.0
# 2     95318  87124       464  Albuquerque, NM   943.0   913.0   916.0   931.0
# 3     95304  87109       812  Albuquerque, NM   856.0   893.0   882.0   878.0
# 4     95303  87108      1076  Albuquerque, NM   500.0   544.0   531.0   534.0
#
#    May-14  Jun-14  ...  Dec-20  Jan-21  Feb-21  Mar-21  Apr-21  May-21  \
# 0   832.0   842.0  ...  1053.0  1055.0  1065.0  1068.0  1093.0  1111.0
# 1   996.0  1011.0  ...  1296.0  1294.0  1277.0  1300.0  1300.0  1320.0
# 2   948.0   959.0  ...  1203.0  1212.0  1239.0  1242.0  1260.0  1294.0
# 3   871.0   883.0  ...  1071.0  1096.0  1126.0  1140.0  1164.0  1184.0
# 4   523.0   499.0  ...   717.0   728.0   715.0   735.0   763.0   771.0
#
#    Jun-21  Jul-21         City  State
# ...

# %%
zillow_df.to_csv('zillow_new.csv')
